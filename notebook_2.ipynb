# %%
import pandas as pd

from power_forecast.logic.get_data.time_features import build_feature_dataframe
# %load_ext autoreload
# %autoreload 2
pd.set_option('display.max_columns', None)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Premier fois que je lance la fonction load_from_pickle = False,
# je veux forcer le calcul des features (et pas le chargement depuis pickle)
df = build_feature_dataframe('raw_data/all_countries.csv', load_from_pickle=True)
# Out:
# ── Step 1: Load raw data ────────────────────────────────────────
#
# ── Step 2: Align start date ─────────────────────────────────────
#
# ── Step 3: Replace outliers ─────────────────────────────────────
#
# ── Step 4: catch24 features (may take > 1/2 min) ──────────────────
#
# ── Step 5: Temporal features ────────────────────────────────────
#
# ── Saving to pickle ─────────────────────────────────────────────
# Saved → raw_data/pickle_files/df_catch24_timeseries.pkl | 30.43 MB

# %%
df
# Out:
#                              AUT    BEL    BGR    CHE    CZE    DEU    DNK  \
# datetime_utc
# 2017-10-01 00:00:00+00:00  19.05  30.44  22.53  34.55  19.07  19.05  19.05
# 2017-10-01 01:00:00+00:00  22.15  25.73  22.52  31.29  19.63  22.15  22.15
# 2017-10-01 02:00:00+00:00  22.90  25.52  22.52  28.17  19.84  22.90  22.90
# 2017-10-01 03:00:00+00:00  23.10  26.84  22.52  27.68  18.74  23.10  23.10
# 2017-10-01 04:00:00+00:00  25.66  27.86  22.51  28.31  17.00  25.66  25.66
# ...                          ...    ...    ...    ...    ...    ...    ...
# 2024-03-31 19:00:00+00:00  66.17  47.01  65.81  74.52  68.37  70.00  70.00
# 2024-03-31 20:00:00+00:00  61.25  43.70  60.90  67.31  63.26  64.51  64.51
# 2024-03-31 21:00:00+00:00  44.99  50.29  48.07  62.86  51.29  54.90  54.90
# 2024-03-31 22:00:00+00:00  40.70  50.32  43.45  44.23  46.39  49.95  49.95
# 2024-03-31 23:00:00+00:00  32.10  44.39  37.15  40.01  42.60  48.98  48.98
#
# ...
